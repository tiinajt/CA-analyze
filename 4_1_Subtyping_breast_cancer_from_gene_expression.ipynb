# %% [markdown]
# ## Using low dimensional embeddings to discover subtypes of breast cancer
#
# This notebook is largely based on https://towardsdatascience.com/reduce-dimensions-for-single-cell-4224778a2d67 (credit to Nikolay Oskolkov).

# %% [markdown]
# https://www.nature.com/articles/s41467-018-07582-3#data-availability

# %%
import pandas as pd
import numpy as np
import GEOparse
from matplotlib import pyplot as plt

# %%
GEO_ID = "GSE48091" # from the article

# %% [markdown]
# #### Exercise 1. load the dataset into `rna_seq` using GEOparse.

# %%
# %load solutions/ex4_1.py
rna_seq = GEOparse.get_GEO(geo=GEO_ID, destdir="./")
# Out:
# 23-May-2022 13:16:23 DEBUG utils - Directory ./ already exists. Skipping.
# 23-May-2022 13:16:23 INFO GEOparse - File already exist: using local version.
# 23-May-2022 13:16:23 INFO GEOparse - Parsing ./GSE48091_family.soft.gz:
# 23-May-2022 13:16:23 DEBUG GEOparse - DATABASE: GeoMiame
# 23-May-2022 13:16:23 DEBUG GEOparse - SERIES: GSE48091
# 23-May-2022 13:16:23 DEBUG GEOparse - PLATFORM: GPL10379
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167774
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167775
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167776
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167777
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167778
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167779
# 23-May-2022 13:16:23 DEBUG GEOparse - SAMPLE: GSM1167780
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167781
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167782
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167783
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167784
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167785
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167786
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167787
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167788
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167789
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167790
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167791
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167792
# 23-May-2022 13:16:24 DEBUG GEOparse - SAMPLE: GSM1167793
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167794
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167795
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167796
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167797
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167798
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167799
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167800
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167801
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167802
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167803
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167804
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167805
# 23-May-2022 13:16:25 DEBUG GEOparse - SAMPLE: GSM1167806
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167807
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167808
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167809
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167810
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167811
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167812
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167813
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167814
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167815
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167816
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167817
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167818
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167819
# 23-May-2022 13:16:26 DEBUG GEOparse - SAMPLE: GSM1167820
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167821
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167822
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167823
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167824
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167825
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167826
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167827
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167828
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167829
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167830
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167831
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167832
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167833
# 23-May-2022 13:16:27 DEBUG GEOparse - SAMPLE: GSM1167834
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167835
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167836
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167837
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167838
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167839
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167840
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167841
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167842
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167843
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167844
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167845
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167846
# 23-May-2022 13:16:28 DEBUG GEOparse - SAMPLE: GSM1167847
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167848
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167849
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167850
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167851
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167852
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167853
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167854
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167855
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167856
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167857
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167858
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167859
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167860
# 23-May-2022 13:16:29 DEBUG GEOparse - SAMPLE: GSM1167861
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167862
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167863
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167864
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167865
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167866
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167867
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167868
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167869
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167870
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167871
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167872
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167873
# 23-May-2022 13:16:30 DEBUG GEOparse - SAMPLE: GSM1167874
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167875
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167876
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167877
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167878
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167879
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167880
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167881
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167882
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167883
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167884
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167885
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167886
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167887
# 23-May-2022 13:16:31 DEBUG GEOparse - SAMPLE: GSM1167888
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167889
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167890
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167891
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167892
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167893
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167894
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167895
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167896
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167897
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167898
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167899
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167900
# 23-May-2022 13:16:32 DEBUG GEOparse - SAMPLE: GSM1167901
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167902
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167903
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167904
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167905
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167906
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167907
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167908
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167909
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167910
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167911
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167912
# 23-May-2022 13:16:33 DEBUG GEOparse - SAMPLE: GSM1167913
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167914
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167915
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167916
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167917
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167918
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167919
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167920
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167921
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167922
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167923
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167924
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167925
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167926
# 23-May-2022 13:16:34 DEBUG GEOparse - SAMPLE: GSM1167927
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167928
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167929
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167930
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167931
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167932
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167933
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167934
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167935
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167936
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167937
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167938
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167939
# 23-May-2022 13:16:35 DEBUG GEOparse - SAMPLE: GSM1167940
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167941
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167942
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167943
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167944
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167945
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167946
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167947
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167948
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167949
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167950
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167951
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167952
# 23-May-2022 13:16:36 DEBUG GEOparse - SAMPLE: GSM1167953
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167954
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167955
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167956
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167957
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167958
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167959
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167960
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167961
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167962
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167963
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167964
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167965
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167966
# 23-May-2022 13:16:37 DEBUG GEOparse - SAMPLE: GSM1167967
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167968
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167969
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167970
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167971
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167972
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167973
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167974
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167975
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167976
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167977
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167978
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167979
# 23-May-2022 13:16:38 DEBUG GEOparse - SAMPLE: GSM1167980
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167981
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167982
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167983
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167984
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167985
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167986
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167987
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167988
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167989
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167990
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167991
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167992
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167993
# 23-May-2022 13:16:39 DEBUG GEOparse - SAMPLE: GSM1167994
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1167995
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1167996
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1167997
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1167998
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1167999
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168000
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168001
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168002
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168003
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168004
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168005
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168006
# 23-May-2022 13:16:40 DEBUG GEOparse - SAMPLE: GSM1168007
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168008
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168009
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168010
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168011
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168012
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168013
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168014
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168015
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168016
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168017
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168018
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168019
# 23-May-2022 13:16:41 DEBUG GEOparse - SAMPLE: GSM1168020
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168021
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168022
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168023
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168024
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168025
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168026
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168027
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168028
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168029
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168030
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168031
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168032
# 23-May-2022 13:16:42 DEBUG GEOparse - SAMPLE: GSM1168033
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168034
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168035
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168036
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168037
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168038
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168039
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168040
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168041
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168042
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168043
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168044
# 23-May-2022 13:16:43 DEBUG GEOparse - SAMPLE: GSM1168045
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168046
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168047
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168048
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168049
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168050
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168051
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168052
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168053
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168054
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168055
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168056
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168057
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168058
# 23-May-2022 13:16:44 DEBUG GEOparse - SAMPLE: GSM1168059
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168060
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168061
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168062
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168063
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168064
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168065
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168066
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168067
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168068
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168069
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168070
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168071
# 23-May-2022 13:16:45 DEBUG GEOparse - SAMPLE: GSM1168072
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168073
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168074
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168075
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168076
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168077
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168078
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168079
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168080
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168081
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168082
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168083
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168084
# 23-May-2022 13:16:46 DEBUG GEOparse - SAMPLE: GSM1168085
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168086
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168087
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168088
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168089
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168090
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168091
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168092
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168093
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168094
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168095
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168096
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168097
# 23-May-2022 13:16:47 DEBUG GEOparse - SAMPLE: GSM1168098
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168099
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168100
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168101
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168102
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168103
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168104
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168105
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168106
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168107
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168108
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168109
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168110
# 23-May-2022 13:16:48 DEBUG GEOparse - SAMPLE: GSM1168111
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168112
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168113
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168114
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168115
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168116
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168117
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168118
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168119
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168120
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168121
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168122
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168123
# 23-May-2022 13:16:49 DEBUG GEOparse - SAMPLE: GSM1168124
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168125
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168126
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168127
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168128
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168129
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168130
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168131
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168132
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168133
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168134
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168135
# 23-May-2022 13:16:50 DEBUG GEOparse - SAMPLE: GSM1168136
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168137
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168138
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168139
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168140
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168141
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168142
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168143
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168144
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168145
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168146
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168147
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168148
# 23-May-2022 13:16:51 DEBUG GEOparse - SAMPLE: GSM1168149
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168150
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168151
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168152
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168153
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168154
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168155
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168156
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168157
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168158
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168159
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168160
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168161
# 23-May-2022 13:16:52 DEBUG GEOparse - SAMPLE: GSM1168162
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168163
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168164
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168165
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168166
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168167
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168168
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168169
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168170
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168171
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168172
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168173
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168174
# 23-May-2022 13:16:53 DEBUG GEOparse - SAMPLE: GSM1168175
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168176
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168177
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168178
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168179
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168180
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168181
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168182
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168183
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168184
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168185
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168186
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168187
# 23-May-2022 13:16:54 DEBUG GEOparse - SAMPLE: GSM1168188
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168189
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168190
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168191
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168192
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168193
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168194
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168195
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168196
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168197
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168198
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168199
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168200
# 23-May-2022 13:16:55 DEBUG GEOparse - SAMPLE: GSM1168201
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168202
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168203
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168204
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168205
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168206
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168207
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168208
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168209
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168210
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168211
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168212
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168213
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168214
# 23-May-2022 13:16:56 DEBUG GEOparse - SAMPLE: GSM1168215
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168216
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168217
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168218
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168219
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168220
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168221
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168222
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168223
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168224
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168225
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168226
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168227
# 23-May-2022 13:16:57 DEBUG GEOparse - SAMPLE: GSM1168228
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168229
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168230
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168231
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168232
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168233
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168234
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168235
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168236
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168237
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168238
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168239
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168240
# 23-May-2022 13:16:58 DEBUG GEOparse - SAMPLE: GSM1168241
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168242
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168243
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168244
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168245
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168246
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168247
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168248
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168249
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168250
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168251
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168252
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168253
# 23-May-2022 13:16:59 DEBUG GEOparse - SAMPLE: GSM1168254
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168255
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168256
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168257
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168258
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168259
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168260
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168261
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168262
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168263
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168264
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168265
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168266
# 23-May-2022 13:17:00 DEBUG GEOparse - SAMPLE: GSM1168267
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168268
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168269
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168270
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168271
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168272
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168273
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168274
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168275
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168276
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168277
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168278
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168279
# 23-May-2022 13:17:01 DEBUG GEOparse - SAMPLE: GSM1168280
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168281
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168282
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168283
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168284
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168285
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168286
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168287
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168288
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168289
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168290
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168291
# 23-May-2022 13:17:02 DEBUG GEOparse - SAMPLE: GSM1168292
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168293
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168294
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168295
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168296
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168297
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168298
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168299
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168300
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168301
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168302
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168303
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168304
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168305
# 23-May-2022 13:17:03 DEBUG GEOparse - SAMPLE: GSM1168306
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168307
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168308
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168309
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168310
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168311
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168312
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168313
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168314
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168315
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168316
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168317
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168318
# 23-May-2022 13:17:04 DEBUG GEOparse - SAMPLE: GSM1168319
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168320
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168321
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168322
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168323
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168324
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168325
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168326
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168327
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168328
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168329
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168330
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168331
# 23-May-2022 13:17:05 DEBUG GEOparse - SAMPLE: GSM1168332
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168333
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168334
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168335
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168336
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168337
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168338
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168339
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168340
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168341
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168342
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168343
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168344
# 23-May-2022 13:17:06 DEBUG GEOparse - SAMPLE: GSM1168345
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168346
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168347
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168348
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168349
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168350
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168351
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168352
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168353
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168354
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168355
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168356
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168357
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168358
# 23-May-2022 13:17:07 DEBUG GEOparse - SAMPLE: GSM1168359
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168360
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168361
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168362
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168363
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168364
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168365
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168366
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168367
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168368
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168369
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168370
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168371
# 23-May-2022 13:17:08 DEBUG GEOparse - SAMPLE: GSM1168372
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168373
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168374
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168375
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168376
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168377
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168378
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168379
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168380
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168381
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168382
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168383
# 23-May-2022 13:17:09 DEBUG GEOparse - SAMPLE: GSM1168384
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168385
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168386
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168387
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168388
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168389
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168390
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168391
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168392
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168393
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168394
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168395
# 23-May-2022 13:17:10 DEBUG GEOparse - SAMPLE: GSM1168396

# %%
dir(rna_seq)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_metadata_as_string',
#  '_get_object_as_soft',
#  '_phenotype_data',
#  'database',
#  'download_SRA',
#  'download_supplementary_files',
#  'geotype',
#  'get_accession',
#  'get_metadata_attribute',
#  'get_type',
#  'gpls',
#  'gsms',
#  'merge_and_average',
#  'metadata',
#  'name',
#  'phenotype_data',
#  'pivot_and_annotate',
#  'pivot_samples',
#  'relations',
#  'show_metadata',
#  'to_soft']

# %%
rna_seq.download_SRA??

# %%
rna_seq.geotype
# Out:
# 'SERIES'

# %%
rna_seq.phenotype_data.shape
# Out:
# (623, 36)

# %%
rna_seq.phenotype_data.shape
# Out:
# (623, 36)

# %%
rna_seq.to_soft('test', False)

# %%
cafs = pd.read_csv('data/CAFs.txt', sep='\t')

# %%
sorted(cafs.cluster.unique())
# Out:
# [1, 2, 3, 4]

# %%
expr = cafs

# %% [markdown]
# ### The expression matrix
# 716 cells has been sequenced, and the expression levels has been assessed for 558 genes. Arranging the cells as rows and genes as columns we obtain an *expression matrix*.

# %%
expr.shape
# Out:
# (716, 558)

# %%
expr
# Out:
#                  1110020A21Rik  1110046J04Rik  1190002F15Rik  1500015A07Rik  \
# SS2_15_0048_A3        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A6        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A5        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A4        0.000000            0.0       0.000000            0.0
# SS2_15_0048_A1       43.324338            0.0       0.000000            0.0
# ...                        ...            ...            ...            ...
# SS2_15_0049_P19       0.000000            0.0       0.000000            0.0
# SS2_15_0049_P18      37.696628            0.0       0.000000            0.0
# SS2_15_0049_P21       0.000000            0.0      53.257827            0.0
# SS2_15_0049_P23       0.000000            0.0       0.000000            0.0
# SS2_15_0049_P22       0.000000            0.0       0.000000            0.0
#
#                  1500015O10Rik  1700010K23Rik  1700012D01Rik  1810011H11Rik  \
# SS2_15_0048_A3        0.000000            0.0            0.0       0.000000
# SS2_15_0048_A6        0.000000            0.0            0.0     230.755035
# SS2_15_0048_A5        0.000000            0.0            0.0     375.177236
# SS2_15_0048_A4      891.488043            0.0            0.0       0.000000
# SS2_15_0048_A1        0.000000            0.0            0.0      20.527119
# ...                        ...            ...            ...            ...
# SS2_15_0049_P19    1012.999120            0.0            0.0       0.000000
# SS2_15_0049_P18    1562.238996            0.0            0.0       0.000000
# SS2_15_0049_P21       5.817578            0.0            0.0     112.228306
# SS2_15_0049_P23    2411.205731            0.0            0.0       0.000000
# SS2_15_0049_P22     122.011558            0.0            0.0     593.342291
#
#                  2010204K13Rik  2310057J18Rik  ...  Wif1  Wisp2         Yy2  \
# SS2_15_0048_A3        0.000000       0.000000  ...   0.0    0.0  107.526495
# SS2_15_0048_A6        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A5        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A4        0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0048_A1       65.766243       0.000000  ...   0.0    0.0    0.000000
# ...                        ...            ...  ...   ...    ...         ...
# SS2_15_0049_P19      37.231979       0.000000  ...   0.0    0.0   21.453518
# SS2_15_0049_P18       0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0049_P21      62.542484      19.583052  ...   0.0    0.0    0.000000
# SS2_15_0049_P23       0.000000       0.000000  ...   0.0    0.0    0.000000
# SS2_15_0049_P22       0.000000       0.000000  ...   0.0    0.0    0.000000
#
#                  Zfp2       Zfp36    Zfp454  Zfp652os  Zfp81     Zfp944  \
# SS2_15_0048_A3    0.0  201.533078  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A6    0.0  175.071938  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A5    0.0  290.743379  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A4    0.0    0.000000  0.000000       0.0    0.0   0.000000
# SS2_15_0048_A1    0.0  768.997431  0.000000       0.0    0.0   2.413509
# ...               ...         ...       ...       ...    ...        ...
# SS2_15_0049_P19   0.0   19.602162  1.869748       0.0    0.0  34.520490
# SS2_15_0049_P18   0.0   41.641731  0.000000       0.0    0.0   0.000000
# SS2_15_0049_P21   0.0   70.246018  0.000000       0.0    0.0   0.000000
# SS2_15_0049_P23   0.0    0.000000  0.000000       0.0    0.0  55.993812
# SS2_15_0049_P22   0.0  390.824106  0.000000       0.0    0.0   0.000000
#
#                  cluster
# SS2_15_0048_A3         1
# SS2_15_0048_A6         1
# SS2_15_0048_A5         1
# SS2_15_0048_A4         2
# SS2_15_0048_A1         1
# ...                  ...
# SS2_15_0049_P19        3
# SS2_15_0049_P18        2
# SS2_15_0049_P21        1
# SS2_15_0049_P23        2
# SS2_15_0049_P22        1
#
# [716 rows x 558 columns]

# %% [markdown]
# Before going further, try to reflect for a moment how you would try to illuminate any pattern in this data, given what you already know.

# %% [markdown]
# #### Plot the expression matrix

# %%
plt.figure(figsize=(8,8))
plt.imshow(expr.values, cmap='Greens', vmax=4000, vmin=0)
plt.title('Expression matrix')
plt.ylabel('Cells')
plt.xlabel('Genes')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Exercise 2. The data is very sparse (most entries are zero), can you quantify how sparse it is? (i.e. how many of the entries are 0)

# %%
# %load solutions/ex4_2.py
np.count_nonzero(expr.values) / np.prod(expr.shape)

# only 20% of the entries are non-zero.
# Out:
# 0.19622154141887427

# %%
print("\n" + "Dimensions of input file: " + str(expr.shape) + "\n")
print("\n" + "Last column corresponds to cluster assignments: " + "\n")
print(expr.iloc[0:4, (expr.shape[1]-4):expr.shape[1]])
X = expr.values[:,0:(expr.shape[1]-1)]
Y = expr.values[:,expr.shape[1]-1] #cluster
X = np.log(X + 1)
# Out:
# Dimensions of input file: (716, 558)
#
#
# Last column corresponds to cluster assignments:
#
#                 Zfp652os  Zfp81  Zfp944  cluster
# SS2_15_0048_A3       0.0    0.0     0.0        1
# SS2_15_0048_A6       0.0    0.0     0.0        1
# SS2_15_0048_A5       0.0    0.0     0.0        1
# SS2_15_0048_A4       0.0    0.0     0.0        2

# %%
cafs.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('int64')], dtype=object)

# %% [markdown]
# ### Decomposing the signals
# Now that we have gained some basic understanding of the data, we see it is fit for machine learning. You have already seen a few techniques to reduce data dimensionality reduction. We start with PCA

# %%
from sklearn.decomposition import PCA

# %%
#from matplotlib import cm
#dir(cm) # available colors

# %% [markdown]
# #### Exercise 3. Perform PCA on the expression data and visualize the results (with colors to represent the ground truth clusters)

# %%
# %load solutions/ex4_3.py
model = PCA()
pca = model.fit_transform(X)
plt.scatter(pca[:, 0], pca[:, 1], c = Y, cmap = 'rainbow', s = 1)
plt.xlabel("PC1", fontsize = 20); plt.ylabel("PC2", fontsize = 20)
# Out:
# Text(0, 0.5, 'PC2')

# %%
plt.plot(model.explained_variance_ratio_[:10])
plt.xticks(range(10));plt.show()

# %% [markdown]
# PCA is completely unsupervised. Linear discriminant analysis (LDA) is often used for the same purpose as PCA (dimensionality reduction), but is strictly speaking not unsupervised.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
model = LinearDiscriminantAnalysis(n_components = 2, priors = None, shrinkage = 'auto', 
                                   solver = 'eigen', store_covariance = False, tol = 0.0001)
lda = model.fit_transform(X, Y)
plt.scatter(lda[:, 0], lda[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.xlabel("LDA1", fontsize = 20); plt.ylabel("LDA2", fontsize = 20)
feature_importances = pd.DataFrame({'Gene':np.array(expr.columns)[:-1], 
                                    'Score':abs(model.coef_[0])})
print(feature_importances.sort_values('Score', ascending = False).head(20))
# Out:
#         Gene      Score
# 422    Rn45s  39.249111
# 64       B2m  12.880958
# 212     Fth1   8.174487
# 287    Lars2   7.385672
# 147     Cst3   6.857356
# 315   Malat1   6.290840
# 420     Rgs5   4.681367
# 524    Timp1   4.486659
# 131   Col3a1   3.229705
# 130   Col1a2   3.062976
# 537  Trmt61b   3.020343
# 145    Crip1   2.991499
# 322      Mgp   2.787057
# 368      Mt1   2.673895
# 400    Postn   2.401428
# 534     Tpm1   2.258763
# 248    Hspa5   2.133318
# 241   Higd1b   2.094767
# 220     Ggt1   2.003810
# 122    Cldn4   1.951643

# %% [markdown]
# The way to interpret the data above: we clearly see the data lay in three clusters, suggesting  we have found 3 different separable expression-signatures. However, we also see one cluster is occupied by 2 clusters (the colors are imposed by the fact that we know the "ground truth", but unsupervised methods are generally used for data exploration in which we do not know of these things.

# %% [markdown]
# # Non-linear methods
#
# # t-SNE
#
# t-SNE is a very popular decomposition technique used in molecular biology, especially for visualization purposes. t-SNE does generally not cope well with high dimensionality, so it is common to first transform the data with PCA and then run this through t-SNE. Here we will do both with and without prereducing the dimensionality.

# %%
from sklearn.manifold import TSNE

# %%
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne = model.fit_transform(X)

# %%
plt.scatter(tsne[:, 0], tsne[:, 1], c = Y, cmap = 'rainbow', s = 2, marker='x')
plt.title('tSNE', fontsize = 20)
plt.xlabel("tSNE1", fontsize = 20)
plt.ylabel("tSNE2", fontsize = 20)
# Out:
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# #### Exercise 4. Reduce the data first with PCA to 30 principal components, then rerun the tSNE on this transformed data.

# %%
# %load solutions/ex4_4.py
X_reduced = PCA(n_components = 30).fit_transform(X)
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne = model.fit_transform(X_reduced)

plt.scatter(tsne[:, 0], tsne[:, 1], c = Y, cmap = 'rainbow', s = 2, marker='x')
plt.title('tSNE on PCA', fontsize = 20)
plt.xlabel("tSNE1", fontsize = 20)
plt.ylabel("tSNE2", fontsize = 20)
# Out:
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# While it can be hard to discern the performance boost of prereduction, we can certainly see that t-SNE performs better than a linear method like PCA. However, non-linearity is no guarantee of success itself. For instance Isomap does not do well with this data.

# %%
from sklearn.manifold import Isomap

# %%
model = Isomap()
isomap = model.fit_transform(X)
plt.scatter(isomap[:, 0], isomap[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.title('ISOMAP')
#plt.colorbar()
plt.xlabel("ISO1")
plt.ylabel("ISO2")
# Out:
# Text(0, 0.5, 'ISO2')

# %% [markdown]
# We should not throw Isomap out the window yet, like most algorithm, there is no one-size-fits-all. Isomap is well suited for tasks without clear clusters, but continuous change is present.

# %% [markdown]
# # UMAP
# A more recent alternative to t-SNE is [UMAP](https://arxiv.org/abs/1802.03426), which also produces high quality visualizations with good separation, and scales better than t-sne with large datasets.

# %%
from umap import UMAP

# %%
print("Performing Uniform Manifold Approximation and Projection (UMAP) ...")
#model = UMAP(n_neighbors = 30, min_dist = 0.3, n_components = 2)
model = UMAP()
umap = model.fit_transform(X) # or X_reduced
# Out:
# Performing Uniform Manifold Approximation and Projection (UMAP) ...

# %%
plt.scatter(umap[:, 0], umap[:, 1], c = Y, cmap = 'viridis', s = 1)
plt.title('UMAP')
#plt.colorbar()
plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
# Out:
# Text(0, 0.5, 'UMAP2')

# %% [markdown]
# #### Conclusion
# In summary, when doing data exploration of gene expression (and other biomedical data), non-linear methods are preferred to linear ones.
